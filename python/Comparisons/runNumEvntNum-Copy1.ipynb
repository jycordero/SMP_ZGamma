# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
HienPath = "/home/jcordero/CMS/data_2016/legacy/SMP_ZG/Files/mumug/Hien/"
HienFiles = {}
HienFiles["Data"] = "runNumber_eventNumber_Mu_Data.csv"
HienFiles["ZG"]   = "runNumber_eventNumber_Mu_Zg.csv"



sample = "legacy"
#date = "20190830"
#date = "20190904"
#date = "20190906"
#date = "20190907"
#date = "20190908"
date = "20190910"

MyLegacyPath   = "/home/jcordero/CMS/JYCMCMS/SMP_ZG/figs/"+sample+"/mumug/"+date+"/"
MyLegacyFiles  = {}
MyLegacyFiles["Data"]   =  "DoubleMuon_2016.csv"
MyLegacyFiles["TT"]     =  "TTTo2L2Nu.csv"
MyLegacyFiles["WW"]     =  "WWTo2L2Nu.csv"
MyLegacyFiles["ZG"]     =  "ZGToLLG.csv"
MyLegacyFiles["DYJets"] =  "DYJets.csv"


sample = "rereco"
#date = "20190907"
#date = "20190908_rerun"
date = "20190910"

MyRerecoPath   = "/home/jcordero/CMS/JYCMCMS/SMP_ZG/figs/"+sample+"/mumug/"+date+"/"
MyRerecoFiles  = {}
MyRerecoFiles["Data"]   =  "DoubleMuon_2016.csv"
MyRerecoFiles["TT"]     =  "TTTo2L2Nu.csv"
MyRerecoFiles["WW"]     =  "WWTo2L2Nu.csv"
MyRerecoFiles["ZG"]     =  "ZGToLLG.csv"
MyRerecoFiles["DYJets"] =  "DYJets.csv"

figpath = "/home/jcordero/CMS/JYCMCMS/SMP_ZG/figs/ComparisonRerecoLegacy/"

# %%
Sample = "Data"
#Sample = "ZG"
H  = pd.read_csv(    HienPath +     HienFiles[Sample])
M  = pd.read_csv(MyLegacyPath + MyLegacyFiles[Sample])
MR = pd.read_csv(MyRerecoPath + MyRerecoFiles[Sample])

# %%
H.head()
# Out:
#    run number   event number   lumi   genWeight   PU wei    PhoPt    PhoEta  \
# 0      275338      194594597    114           0        0  18.8307  2.356670
# 1      275338      196080736    115           0        0  15.1622  0.325034
# 2      275338      270609925    159           0        0  16.6022 -2.139460
# 3      275338      320108218    189           0        0  16.4976 -2.471360
# 4      275338      320514286    189           0        0  27.4661  0.303359
#
#     lept0_pt   lept0_eta   lept1_pt   lept1_eta   z_mass
# 0    43.5702    0.729275    39.7036   -0.129689  90.9296
# 1    56.6230   -2.013020    42.3122   -1.894620  91.0455
# 2    65.7023    0.243021    37.5646    1.737180  92.1407
# 3    47.4084    0.862810    40.4209    1.466110  91.7069
# 4    37.0096   -0.914206    22.6788   -0.418976  55.8876

# %%
M.head()
# Out:
#    Unnamed: 0  runNumber   evtNumber  lumiSection  genWeight  eventWeight  \
# 0           0     273158   228370674          144          1          1.0
# 1           1     273158   228632488          144          1          1.0
# 2           2     273725   833155222          546          1          1.0
# 3           3     273725  2807300909         1953          1          1.0
# 4           4     273725   837665976          549          1          1.0
#
#    leptonOnePt  leptonOneEta  leptonOnePhi  leptonTwoPt        ...         \
# 0    82.282364      1.308625     -2.291850    20.813297        ...
# 1    52.824060      2.236778      0.054856    39.614240        ...
# 2    63.527466      1.399583      2.306606    45.242416        ...
# 3    41.567993      1.692016      0.761896    23.370693        ...
# 4    45.725870     -1.216825     -0.499231    34.633766        ...
#
#    dileptonDR  l1PhotonDEta  l1PhotonDPhi  l1PhotonDR  l2PhotonDEta  \
# 0    2.622744      0.253881      3.039727    3.050311      0.290208
# 1    2.400320      0.185465      2.662979    2.669429      0.755827
# 2    1.902624      0.713072      2.805596    2.894796      1.299251
# 3    2.515446      1.955207      2.520638    3.190055      0.206588
# 4    3.040845      1.856146      2.683443    3.262843      2.989578
#
#    l2PhotonDPhi  l2PhotonDR  dileptonPhotonDEta  dileptonPhotonDPhi  \
# 0      0.677770    0.737288            0.558871            3.070359
# 1      1.288635    1.493939            0.471305            2.776172
# 2      1.667514    2.113920            1.435316            2.783418
# 3      2.476426    2.485028            1.632395            2.956731
# 4      0.778029    3.089160            4.032686            2.896650
#
#    dileptonPhotonDR
# 0          3.120807
# 1          2.815894
# 2          3.131700
# 3          3.377421
# 4          4.965192
#
# [5 rows x 43 columns]

# %%
MR.head()
# Out:
#    Unnamed: 0  runNumber   evtNumber  lumiSection  genWeight  eventWeight  \
# 0           0     274442  1216138518          707          1          1.0
# 1           1     274442  1217358617          707          1          1.0
# 2           2     274442  1287520424          751          1          1.0
# 3           3     274442  1288720153          752          1          1.0
# 4           4     274968  1337961588          705          1          1.0
#
#    leptonOnePt  leptonOneEta  leptonOnePhi  leptonTwoPt        ...         \
# 0    44.834408      1.478835      0.762093    25.495914        ...
# 1    32.458550      0.203093      0.351757    28.005526        ...
# 2    72.820770      1.389354      1.646731    30.676641        ...
# 3    28.692024      0.311294     -1.341298    26.034426        ...
# 4   120.487290     -1.177169      0.490793   110.864456        ...
#
#    dileptonDR  l1PhotonDEta  l1PhotonDPhi  l1PhotonDR  l2PhotonDEta  \
# 0    2.902628      0.804893      0.841846    1.164713      0.077098
# 1    2.365833      1.890895      2.915357    3.474880      2.180344
# 2    2.375053      0.599234      1.242293    1.379265      0.592453
# 3    1.852430      0.578755      2.019047    2.100359      0.866518
# 4    0.815728      0.186700      2.323822    2.331310      0.240984
#
#    l2PhotonDPhi  l2PhotonDR  dileptonPhotonDEta  dileptonPhotonDPhi  \
# 0      2.675957    2.677068            1.585031            1.259271
# 1      1.019768    2.407037            2.485489            2.367796
# 2      1.132751    1.278329            0.009702            0.845086
# 3      3.105396    3.224025            0.295768            2.566657
# 4      1.509902    1.529012            0.141880            1.934788
#
#    dileptonPhotonDR
# 0          2.024373
# 1          3.432799
# 2          0.845142
# 3          2.583642
# 4          1.939983
#
# [5 rows x 43 columns]

# %%
A = getattr(M,'runNumber')
#B = getattr(H,'run number')
B = getattr(MR,'runNumber')

#LA,LB = 'JL','H'
LA,LB = 'JL','JR'

plt.figure()
plt.hist(
        [A,B],
        histtype = 'step',
        bins     = 100,
        label    = [LA,LB],
        )
plt.legend()
plt.title("Run Number")
plt.grid(linestyle = '--')
plt.show()

# %%
A = getattr(M,'evtNumber')
#B = getattr(H,' event number')
#A = getattr(H,' event number')
B = getattr(MR,'evtNumber')

plt.figure()
plt.hist(
        [A,B],
        histtype = 'step',
        #range    = [6000,1000000], 
        #bins     = 90,
        #range    = [6e3,5000000e3], 
        bins     = 1200,
        label    = [LA,LB],
        )
plt.legend()
plt.title("Event Number")
plt.grid(linestyle = '--')
plt.show()

# %%
print("=========== Hien ===========")
for k in H.keys():
    print(k)
    
print("========== Joseph ===========")
for k in M.keys():
    print(k)
# Out:
# =========== Hien ===========
# run number
#  event number
#  lumi
#  genWeight
#  PU wei
#  PhoPt
#  PhoEta
#  lept0_pt
#  lept0_eta
#  lept1_pt
#  lept1_eta
#  z_mass
# ========== Joseph ===========
# Unnamed: 0
# runNumber
# evtNumber
# lumiSection
# genWeight
# eventWeight
# leptonOnePt
# leptonOneEta
# leptonOnePhi
# leptonTwoPt
# leptonTwoEta
# leptonTwoPhi
# dileptonPt
# dileptonEta
# dileptonPhi
# llgPt
# llgEta
# llgPhi
# dileptonM
# llgM
# photonOnePt
# photonOneEta
# photonOnePhi
# photonOneR9
# photonOneMVA
# passElectronVeto
# photonOneSieie
# photonOneHoverE
# photonOneIneu
# photonOneIch
# photonOneIph
# dileptonDEta
# dileptonDPhi
# dileptonDR
# l1PhotonDEta
# l1PhotonDPhi
# l1PhotonDR
# l2PhotonDEta
# l2PhotonDPhi
# l2PhotonDR
# dileptonPhotonDEta
# dileptonPhotonDPhi
# dileptonPhotonDR

# %%
#Hien = True
Hien = False

lumiA = getattr(M,'lumiSection').values
if Hien:
    lumiB  = getattr(H,' lumi').values
else:
    lumiB = getattr(MR,'lumiSection').values


runA = getattr(M,  'runNumber').values
if Hien:
    runB = getattr(H,  'run number').values
else:
    runB = getattr(MR,  'runNumber').values


evtNumA = getattr(M,  'evtNumber').values
if Hien:
    evtNumB = getattr(H,' event number').values
else:
    evtNumB = getattr(MR,  'evtNumber').values

# %%
M
# Out:
#         Unnamed: 0  runNumber   evtNumber  lumiSection  genWeight  \
# 0                0     273158   228370674          144          1
# 1                1     273158   228632488          144          1
# 2                2     273725   833155222          546          1
# 3                3     273725  2807300909         1953          1
# 4                4     273725   837665976          549          1
# 5                5     273725   837781707          549          1
# 6                6     273725   838364278          549          1
# 7                7     273725  2871019774         2002          1
# 8                8     273725  3135740775         2210          1
# 9                9     273725   836257087          548          1
# 10              10     273725  2874632355         2005          1
# 11              11     273409   361023072          203          1
# 12              12     273502   222025195          218          1
# 13              13     273502   223660323          219          1
# 14              14     273502   224034278          220          1
# 15              15     273725  2822725888         1965          1
# 16              16     273725  2822558284         1965          1
# 17              17     273725  2822342281         1965          1
# 18              18     273725  2813441363         1958          1
# 19              19     273725  2812949190         1958          1
# 20              20     273725  2815458984         1959          1
# 21              21     273730   849551527          792          1
# 22              22     274146    31085007           20          1
# 23              23     274146    30902095           20          1
# 24              24     274146    35128063           22          1
# 25              25     274146    31885148           21          1
# 26              26     274146    32488831           21          1
# 27              27     274146    91008150           53          1
# 28              28     273158    33915503           24          1
# 29              29     273158  1734043431         1249          1
# ...            ...        ...         ...          ...        ...
# 332371      332371     282735   973552768          483          1
# 332372      332372     282735   973323587          483          1
# 332373      332373     282735   974953115          483          1
# 332374      332374     282735   962812121          477          1
# 332376            0.429099          0.549025
# 332377            2.594123          2.674745
# 332378            3.039751          3.554850
# 332379            2.240746          2.244613
# 332380            1.993395          2.723078
# 332381            1.603401          3.972777
# 332382            0.410594          1.387623
# 332383            2.680594          4.350170
# 332384            2.299175          3.799988
# 332385            0.010921          4.630666
# 332386            3.086857          3.307376
# 332387            2.966507          3.092331
# 332388            2.472275          2.498750
# 332389            2.609197          3.583460
# 332390            2.603272          3.957793
# 332391            2.372512          2.377362
# 332392            3.062397          3.508936
# 332393            2.734735          3.268760
# 332394            2.991110          5.166433
# 332395            0.330213          1.914859
# 332396            2.689144          4.533331
# 332397            3.096615          3.099814
# 332398            1.688249          3.066836
# 332399            2.489954          2.866427
# 332400            1.280250          2.414151
#
# [332401 rows x 43 columns]

# %%
print("=============== COUNT ====================\n")
print(
      "A:: "  , len(evtNumA), "\n"
      "B:: "  , len(evtNumB),"\n"
      "I:: "  , len(np.intersect1d(lumiA,lumiB))," Lumi\n"
      "I:: "  , len(np.intersect1d(runB,runA))," run\n"
      "I:: "  , len(np.intersect1d(evtNumB,evtNumA))," event\n"
      "I%A:: ", len(np.intersect1d(evtNumB,evtNumA))/len(evtNumA)*100," event\n"
      "I%B:: ", len(np.intersect1d(evtNumB,evtNumA))/len(evtNumB)*100," event\n"
    )
print("=============== Unique ====================\n")
print(
      "A:: ",len(set(evtNumA))/len(evtNumA)*100," Evt\n"
      "A:: ",len(set(   runA))/len(   runA)*100," run\n"
      "A:: ",len(set(  lumiA))/len(  lumiA)*100," lumi\n"
      "\n"
      "B:: ",len(set(evtNumB))/len(evtNumB)*100," Evt\n"
      "B:: ",len(set(   runB))/len(   runB)*100," run\n"
      "B:: ",len(set(  lumiB))/len(  lumiB)*100," lumi\n"
     )
print("===========================================")
# Out:
# =============== COUNT ====================
#
# A::  332401
# B::  332352
# I::  3296  Lumi
# I::  390  run
# I::  293872  event
# I%A::  88.40887963634285  event
# I%B::  88.42191411515502  event
#
# =============== Unique ====================
#
# A::  99.99398317092908  Evt
# A::  0.1173281668827711  run
# A::  0.9981919428641911  lumi
#
# B::  99.99247785480453  Evt
# B::  0.11734546504910456  run
# B::  0.9971355671095706  lumi
#
# ===========================================

# %%
density = True;
#density = False;

A = getattr(M,"leptonOnePt")
B = getattr(MR,"leptonOnePt")
#B = getattr(H," lept0_pt"),

plt.figure()
plt.hist(
        [A,B],
        histtype = 'step',
        range    = [0,200],
        bins     = 40,
        label    = [LA,LB],
        density  = density,
        )
plt.legend()
plt.title('Leading Lepton Pt')
plt.grid(linestyle='--')

A = getattr(M,"leptonTwoPt")
B = getattr(MR,"leptonTwoPt")
#B = getattr(H," lept1_pt")
plt.figure()
plt.hist(
        [A,B],
        histtype = 'step',
        range    = [0,80],
        bins     = 40,
        label    = [LA,LB],
        density  = density,
        )
plt.legend()
plt.title('Trailing Lepton Pt')
plt.grid(linestyle='--')

A = getattr(M,"photonOnePt")
B = getattr(MR,"photonOnePt")
#B = getattr(H," PhoPt")
plt.figure()
plt.hist(
        [A,B],
        histtype = 'step',
        range    = [0,80],
        bins     = 40,
        label    = [LA,LB],
        density  = density,
        )
plt.legend()
plt.title("Photon Pt")
plt.grid(linestyle='--')
plt.show()

# %%
density = True;
#density = False;

A = getattr(M,"leptonOneEta")
B = getattr(MR,"leptonOneEta")
#B = getattr(H," lept0_eta")
plt.figure()
plt.hist(
        [A,B],
        histtype = 'step',
        range    = [-2.5,2.5],
        bins     = 40,
        label    = [LA,LB],
        density  = density,
        )
plt.legend()
plt.title('Leading Lepton Eta')
plt.grid(linestyle='--')

A = getattr(M,"leptonTwoEta")
B = getattr(MR,"leptonTwoEta")
#B = getattr(H," lept1_eta")
plt.figure()
plt.hist(
        [A,B],
        histtype = 'step',
        range    = [-2.5,2.5],
        bins     = 40,
        label    = [LA,LB],
        density  = density,
        )
plt.legend()
plt.title('Trailing Lepton Eta')
plt.grid(linestyle='--')

A = getattr(M,"photonOneEta")
B = getattr(MR,"photonOneEta")
#B = getattr(H," PhoEta")
plt.figure()
plt.hist(
        [A,B],
        histtype = 'step',
        range    = [-3.5,3.5],
        bins     = 40,
        label    = [LA,LB],
        density  = density,
        )
plt.legend()
plt.title("Photon Eta")
plt.grid(linestyle='--')
plt.show()

# %%
dilepEtaA = getattr(M,"leptonOneEta")-getattr(M,"leptonTwoEta")
dilepEtaB = getattr(MR,"leptonOneEta")-getattr(MR,"leptonTwoEta")
#dilepEtaB = getattr(H," lept0_eta")-getattr(H," lept1_eta")

lep1gmEtaA = getattr(M,"leptonOneEta")-getattr(M,"photonOneEta")
lep1gmEtaB = getattr(MR,"leptonOneEta")-getattr(MR,"photonOneEta")
#lep1gmEtaH = getattr(H," lept0_eta")-getattr(H," PhoEta")

lep2gmEtaA = getattr(M,"leptonTwoEta")-getattr(M,"photonOneEta")
lep2gmEtaB = getattr(MR,"leptonTwoEta")-getattr(MR,"photonOneEta")
#lep2gmEtaB = getattr(H," lept1_eta")-getattr(H," PhoEta")

# %%
density = True;
#density = False;

plt.figure()
plt.hist(
        [dilepEtaA,dilepEtaB],
        histtype = 'step',
        range    = [-2.5,2.5],
        bins     = 40,
        label    = [LA,LB],
        density  = density,
        )
plt.legend()
plt.title('Dilepton Eta')
plt.grid(linestyle='--')

plt.figure()
plt.hist(
        [lep1gmEtaA,lep1gmEtaB],
        histtype = 'step',
        range    = [-2.5,2.5],
        bins     = 40,
        label    = [LA,LB],
        density  = density,
        )
plt.legend()
plt.title('Lep1-GM Eta')
plt.grid(linestyle='--')

plt.figure()
plt.hist(
        [lep2gmEtaA,lep2gmEtaB],
        histtype = 'step',
        range    = [-2.5,2.5],
        bins     = 40,
        label    = [LA,LB],
        density  = density,
        )
plt.legend()
plt.title('Lep2-GM Eta')
plt.grid(linestyle='--')

# %%
if Hien:
    Inter = np.intersect1d(getattr(H,' event number'),getattr(M,  'evtNumber'))
else:
    Inter = np.intersect1d(getattr(MR,'evtNumber'),getattr(M,  'evtNumber'))

# %%
if Hien:
    A = getattr(H,' event number')
else:
    A = getattr(MR,'evtNumber')


insideMR  = []
outsideMR = []
for evtMR,i in zip(A,range(len(A))):
    if not( evtMR in Inter ):
        outsideMR.append(i)
    else :
        insideMR.append(i)

# %%
#A = M
if Hien:
    A = H   
else:
    A = MR


if A.keys()[1] == "runNumber":
    ranges = {
        "photonOnePhi":[40,[-3.5,3.5]],
        "photonOneEta":[40,[-3.5,3.5]],
        "photonOnePt" :[20,[15,85]],
        
        "leptonOnePhi":[40,[-3.5,3.5]],
        "leptonOneEta":[40,[-3.5,3.5]],
        "leptonOnePt" :[40,[18,200]],
        #"leptonTwoPt" :[40,[18,120]],
    
        "leptonTwoPhi":[40,[-3.5,3.5]],
        "leptonTwoEta":[40,[-3.5,3.5]],
        "leptonTwoPt" :[40,[18,80]],
    
    
        #"dileptonM"   :[40,[50,200]],
        "dileptonM"   :[40,[50,120]],
        #"dileptonM"   :[40,[50,85]],
    
        "llgM"        :[40,[50,200]],
    
        'dileptonPhotonDEta':[40,[0,5]],
        'dileptonPhotonDPhi':[40,[0,3.5]],
        'l1PhotonDEta':[40,[0,5]],
        'l1PhotonDPhi':[40,[0,3.5]],
    
        'l2PhotonDEta':[40,[0,5]],
        'l2PhotonDPhi':[40,[0,3.5]],
        }
else:
    ranges = {
            " PhoEta":[40,[-3.5,3.5]],
            " PhoPt" :[20,[15,85]],

            " lept0_eta":[40,[-3.5,3.5]],
            " lept0_pt" :[40,[18,200]],

            " lept1_eta":[40,[-3.5,3.5]],
            " lept1_pt" :[40,[18,80]],

            " z_mass"   :[40,[50,120]],
            }

for r in ranges:
    plt.figure()
    plt.hist(
            [getattr(A,r).values[outsideMR],getattr(A,r)[insideMR]],
            histtype = 'step',
            bins     = ranges[r][0],
            range    = ranges[r][1],
            label    = ['nonOverlap','Overlap'],
            density  = True,
            #density  = False,
            )
    plt.grid(linestyle='--')
    plt.xlabel(r)
    plt.legend()
    plt.show()

# %%
B = getattr(M,'evtNumber')

insideM  = []
outsideM = []
for evtM,i in zip(B,range(len(B))):
    if not( evtM in Inter ):
        outsideM.append(i)
    else :
        insideM.append(i)

# %%
A = M
#A = MR


if A.keys()[1] == "runNumber":
    ranges = {
        "photonOnePhi":[40,[-3.5,3.5]],
        "photonOneEta":[40,[-3.5,3.5]],
        "photonOnePt" :[20,[15,85]],
        
        "leptonOnePhi":[40,[-3.5,3.5]],
        "leptonOneEta":[40,[-3.5,3.5]],
        "leptonOnePt" :[40,[18,200]],
        #"leptonTwoPt" :[40,[18,120]],
    
        "leptonTwoPhi":[40,[-3.5,3.5]],
        "leptonTwoEta":[40,[-3.5,3.5]],
        "leptonTwoPt" :[40,[18,80]],
    
    
        #"dileptonM"   :[40,[50,200]],
        "dileptonM"   :[40,[50,120]],
        #"dileptonM"   :[40,[50,85]],
    
        "llgM"        :[40,[50,200]],
    
        'dileptonPhotonDEta':[40,[0,5]],
        'dileptonPhotonDPhi':[40,[0,3.5]],
        'l1PhotonDEta':[40,[0,5]],
        'l1PhotonDPhi':[40,[0,3.5]],
    
        'l2PhotonDEta':[40,[0,5]],
        'l2PhotonDPhi':[40,[0,3.5]],
        }
else:
    ranges = {
            " PhoEta":[40,[-3.5,3.5]],
            " PhoPt" :[20,[15,85]],

            " lept0_eta":[40,[-3.5,3.5]],
            " lept0_pt" :[40,[18,200]],

            " lept1_eta":[40,[-3.5,3.5]],
            " lept1_pt" :[40,[18,80]],

            " z_mass"   :[40,[50,120]],
            }

for r in ranges:
    plt.figure()
    plt.hist(
            [getattr(A,r).values[outsideM],getattr(A,r)[insideM]],
            histtype = 'step',
            bins     = ranges[r][0],
            range    = ranges[r][1],
            label    = ['nonOverlap','Overlap'],
            density  = True,
            #density  = False,
            )
    plt.grid(linestyle='--')
    plt.xlabel(r)
    plt.legend()
    plt.show()
'''
#var = "photonOnePt"
#var = "photonOneEta"
#var = "leptonOnePt"
#var = "leptonOneEta"
#var = "leptonTwoPt"
#var = "leptonTwoEta"
#var = "dileptonM"
var = "llgM"

plt.figure()
plt.hist(
        [getattr(A,var).values[outside],getattr(A,var)],
        histtype = 'step',
        bins     = ranges[var][0],
        range    = ranges[var][1],
        label    = ['nonOverlap','Total'],
        density  = True,
        #density  = False,
        )
plt.grid(linestyle='--')
plt.xlabel(var)
plt.legend()
plt.show()    
''';

# %%
nonOverlap = np.array(set(getattr(H,' event number')) - set(Inter))
ind = getattr(H,' event number')==nonOverlap

# %%
evtNumM = getattr(M,'evtNumber')
evtNumH = getattr(H,' event number')

# %%
for k in MR.keys():
    print(k)
# Out:
# Unnamed: 0
# runNumber
# evtNumber
# lumiSection
# genWeight
# eventWeight
# leptonOnePt
# leptonOneEta
# leptonOnePhi
# leptonTwoPt
# leptonTwoEta
# leptonTwoPhi
# dileptonPt
# dileptonEta
# dileptonPhi
# llgPt
# llgEta
# llgPhi
# dileptonM
# llgM
# photonOnePt
# photonOneEta
# photonOnePhi
# photonOneR9
# photonOneMVA
# passElectronVeto
# photonOneSieie
# photonOneHoverE
# photonOneIneu
# photonOneIch
# photonOneIph
# dileptonDEta
# dileptonDPhi
# dileptonDR
# l1PhotonDEta
# l1PhotonDPhi
# l1PhotonDR
# l2PhotonDEta
# l2PhotonDPhi
# l2PhotonDR
# dileptonPhotonDEta
# dileptonPhotonDPhi
# dileptonPhotonDR

# %%
Yield = {}
'''
#---------- nTuple -------
Yield["legacy"] =  {"B":4.43546e7,
                    "C":1.1801e7,
                    "D":1.86709e7,
                    "E":2.03186e7,
                    "F":1.44343e7,
                    "G":2.93905e7,
                    "H":2.55204e7,
                    }
Yield["rereco"] =  {"B":4.79515e7,
                    "C":1.36287e7,
                    "D":2.01648e7,
                    "E":2.0925e7,
                    "F":1.4914e7,
                    "G":3.08041e7,
                    "H":2.88416e7,
                    }
''';
#---------- HLT -------
Yield["legacy"] =  {"B":1.49714e7,
                    "C":7.36151e6,
                    "D":1.18623e7,
                    "E":1.30677e7,
                    "F":1.08151e7,
                    "G":2.19887e7,
                    "H":1.70038e7,
                    }
Yield["rereco"] =  {"B":1.49718e7,
                    "C":7.37378e6,
                    "D":1.18682e7,
                    "E":1.3093e7,
                    "F":1.08148e7,
                    "G":2.19886e7,
                    "H":1.7016e7,
                    }

# %%
s = {}
for Y in Yield:
    s[Y] = 0
    for k in Yield[Y]:
        s[Y] += Yield[Y][k]
s
# Out:
# {'legacy': 97070510.0, 'rereco': 97126180.0}

# %%
(1 - s["legacy"]/s["rereco"])*100
# Out:
# 0.05731719295456461

# %%
ind[ecal] = {}
ind[ecal]["legacy"] = getattr(M,"photonOneEta") <  1.479
indec["rereco"] = getattr(MR,"photonOneEta") <  1.479

indEE = {}
indEE["legacy"] = getattr(M,"photonOneEta") >=  1.479
indEE["rereco"] = getattr(MR,"photonOneEta") >=  1.479

# %%
merg = pd.merge(M[indEB],MR, how = 'inner',on='evtNumber')

# %%
#merg = pd.merge(M,MR, how = 'inner',on='evtNumber')

# %%
'''
ECAL = ["EE","EB"]
indx,indy = {},{}
for ecal in ECAL:
    if ecal == "EB":
        indx[ecal]  = getattr(merg,"photonOneEta_x") <  1.479
        indy[ecal]  = getattr(merg,"photonOneEta_y") <  1.479
    else:
        indx[ecal]  = getattr(merg,"photonOneEta_x") >= 1.479
        indy[ecal]  = getattr(merg,"photonOneEta_y") >= 1.479

''';

# %%
print(sum(indx["EE"]),sum(indy["EE"]))
print(sum(indx["EB"]),sum(indy["EB"]))
# Out:
# 32074 32057
# 261857 261874

# %%
parts = ["leptonOne","leptonTwo"]
var = ["Pt","Eta"]
VAR = [p+v for p in parts for v in var]
#for p in parts:
#    for v in var:
#        VAR.append(p+v)
var = ["Pt","Eta","Sieie","HoverE","R9","Ineu","Ich","Iph"]
VAR += ["photonOne"+v for v in var]
VAR += ["dileptonM"]
VAR += ["llgM"]

plotSetDiff = {
        "photonOneEta"   : [40,[-0.004,0.004]],
        "photonOnePt"    : [65,[-10,10]],
        "photonOneSieie" : [60,[-0.01,0.01]],
        "photonOneHoverE": [60,[-0.02,0.02]],
        "photonOneR9"    : [60,[-0.25,0.25]],
        "photonOneIneu"  : [60,[-0.25,0.25]],
        "photonOneIch"   : [60,[-0.25,0.25]],
        "photonOneIph"   : [60,[-1.5,1]],

        "leptonOneEta":[40,[-0.00055,0.00055]],
        "leptonOnePt" :[40,[-5,5]],

        "leptonTwoEta":[40,[-0.00055,0.00055]],
        "leptonTwoPt" :[40,[-5,5]],

        "dileptonM"   :[40,[-5,5]],

        "llgM"        :[40,[-30,30]],

        'dileptonPhotonDEta':[40,[0,5]],
        'dileptonPhotonDPhi':[40,[0,3.5]],
        'l1PhotonDEta':[40,[0,5]],
        'l1PhotonDPhi':[40,[0,3.5]],

        'l2PhotonDEta':[40,[0,5]],
        'l2PhotonDPhi':[40,[0,3.5]],
        }
        
plotSet = {
        "photonOnePhi"   : [40,[-3.5,3.5]],
        "photonOneEta"   : [40,[-3.5,3.5]],
        "photonOnePt"    : [50,[10,85]],
        "photonOneSieie" : [60,[0,0.045]],
        "photonOneHoverE": [60,[0.001,0.1]],
        "photonOneR9"    : [60,[0,1]],
        "photonOneIneu"  : [60,[0.001,4]],
        "photonOneIch"   : [60,[0.001,3]],
        "photonOneIph"   : [60,[0.001,6.5]],    
    
        "leptonOnePhi" : [40,[-3.5,3.5]],
        "leptonOneEta" : [40,[-3.5,3.5]],
        "leptonOnePt"  : [40,[18,200]],
        #"leptonTwoPt" : [40,[18,120]],
    
        "leptonTwoPhi" : [40,[-3.5,3.5]],
        "leptonTwoEta" : [40,[-3.5,3.5]],
        "leptonTwoPt"  : [40,[18,80]],
    
    
        #"dileptonM"   :[40,[50,200]],
        "dileptonM"   :[40,[50,120]],
        #"dileptonM"   :[40,[50,85]],
    
        "llgM"        :[40,[50,200]],
    
        'dileptonPhotonDEta':[40,[0,5]],
        'dileptonPhotonDPhi':[40,[0,3.5]],
        'l1PhotonDEta':[40,[0,5]],
        'l1PhotonDPhi':[40,[0,3.5]],
    
        'l2PhotonDEta':[40,[0,5]],
        'l2PhotonDPhi':[40,[0,3.5]],
        }


histo = {}
cb = {}
cdf = {}
for v in VAR:
    for ecal in ECAL:
        fig = plt.figure(figsize=(20,6))
        
        L = np.array(getattr(merg,v+"_x"))
        R = np.array(getattr(merg,v+"_y"))
        ###############################################

        plt.subplot(1,3,1)
        plt.hist(
                [L[indx[ecal]],R[indy[ecal]]],
                histtype = 'step',
                range    = plotSet[v][1],
                bins     = plotSet[v][0],
                label    = ['rerecy','legacy']
                )
        plt.title("Rereco-Legacy Comparison")
        plt.xlabel(v+ecal)
        plt.grid(linestyle = '--')
        plt.legend()
        #fig.savefig(figpath+"/"+v+"Diff.png")

        ###############################################

        if len(L[indx[ecal]]) > len(R[indy[ecal]]):
            maxLenght = len(R[indy[ecal]])
        else:
            maxLenght = len(L[indx[ecal]])
        plt.subplot(1,3,2)
        histo[v] = plt.hist(
                L[indx[ecal]][:maxLenght]-R[indy[ecal]][:maxLenght],
                histtype = 'step',
                range    = plotSetDiff[v][1],
                bins     = plotSetDiff[v][0],
                )
        plt.title("Legacy-Rereco Comparison")
        plt.xlabel(v+ecal+" diff")
        plt.grid(linestyle = '--')
        #fig.savefig(figpath+"/"+v+"Diff.png")

        ###############################################

        cb[v] = (histo[v][1][1:]+histo[v][1][:-1])/2
        #N = sum(getattr(merg,v+"_x"))
        N = sum(histo[v][0])

        cdf[v] = {}
        for c in cb[v]:
            cdfi = sum(histo[v][0][c<cb[v]])/N
            cdf[v][c] = cdfi
            #print(c,cdfi)

        plt.subplot(1,3,3)
        plt.plot(cb[v],cdf[v].values())
        plt.title(v+"Diff CDF")
        plt.xlabel(v+ecal+" diff")
        plt.grid(linestyle='--')
        plt.show()
        #fig.savefig(figpath+"PtCDF.png")    

        ###############################################

        fig.savefig(figpath+"/"+v+ecal+".png")

# %%
var = ["photonOnePt","leptonOnePt","leptonTwoPt","dileptonM"]
ptcut = {
        "photonOnePt":15,
        "leptonOnePt":25,
        "leptonTwoPt":20,
        "dileptonM":50,
        }
v = "photonOnePt"

# %%
count = {}
for v in var:
    print("-------"+v+"-------")
    count[v] = {}
    edge = np.array(histo[v][1])[histo[v][1]>=0]+ptcut[v]
    for i in range(1,len(edge)):
        print(round(cb[v][cb[v]>=0][i-1]+ptcut[v],2),"|",round(edge[i-1],2),"|",round(edge[i],2))
        #cbLabel = round(cb[v][cb[v]>=0][i-1]+ptcut,2)
        cbLabel = cb[v][cb[v]>=0][i-1]+ptcut[v]
        count[v][cbLabel] = sum(np.logical_and(getattr(merg,v+"_x") > edge[i-1], getattr(merg,v+"_x") <= edge[i]))
# Out:
# -------photonOnePt-------
# 15.0 | 15.15 | 15.46
# 15.31 | 15.46 | 15.77
# 15.62 | 15.77 | 16.08
# 15.92 | 16.08 | 16.38
# 16.23 | 16.38 | 16.69
# 16.54 | 16.69 | 17.0
# 16.85 | 17.0 | 17.31
# 17.15 | 17.31 | 17.62
# 17.46 | 17.62 | 17.92
# 17.77 | 17.92 | 18.23
# 18.08 | 18.23 | 18.54
# 18.38 | 18.54 | 18.85
# 18.69 | 18.85 | 19.15
# 19.0 | 19.15 | 19.46
# 19.31 | 19.46 | 19.77
# 19.62 | 19.77 | 20.08
# 19.92 | 20.08 | 20.38
# 20.23 | 20.38 | 20.69
# 20.54 | 20.69 | 21.0
# 20.85 | 21.0 | 21.31
# 21.15 | 21.31 | 21.62
# 21.46 | 21.62 | 21.92
# 21.77 | 21.92 | 22.23
# 22.08 | 22.23 | 22.54
# 22.38 | 22.54 | 22.85
# 22.69 | 22.85 | 23.15
# 23.0 | 23.15 | 23.46
# 23.31 | 23.46 | 23.77
# 23.62 | 23.77 | 24.08
# 23.92 | 24.08 | 24.38
# 24.23 | 24.38 | 24.69
# 24.54 | 24.69 | 25.0
# -------leptonOnePt-------
# 25.04 | 25.0 | 25.08
# 25.11 | 25.08 | 25.15
# 25.19 | 25.15 | 25.22
# 25.26 | 25.22 | 25.3
# 25.34 | 25.3 | 25.38
# 25.41 | 25.38 | 25.45
# 25.49 | 25.45 | 25.52
# 25.56 | 25.52 | 25.6
# 25.64 | 25.6 | 25.68
# 25.71 | 25.68 | 25.75
# 25.79 | 25.75 | 25.82
# 25.86 | 25.82 | 25.9
# 25.94 | 25.9 | 25.98
# 26.01 | 25.98 | 26.05
# 26.09 | 26.05 | 26.12
# 26.16 | 26.12 | 26.2
# 26.24 | 26.2 | 26.28
# 26.31 | 26.28 | 26.35
# 26.39 | 26.35 | 26.42
# 26.46 | 26.42 | 26.5
# -------leptonTwoPt-------
# 20.02 | 20.0 | 20.05
# 20.08 | 20.05 | 20.1
# 20.12 | 20.1 | 20.15
# 20.18 | 20.15 | 20.2
# 20.23 | 20.2 | 20.25
# 20.27 | 20.25 | 20.3
# 20.32 | 20.3 | 20.35
# 20.38 | 20.35 | 20.4
# 20.42 | 20.4 | 20.45
# 20.48 | 20.45 | 20.5
# 20.52 | 20.5 | 20.55
# 20.58 | 20.55 | 20.6
# 20.62 | 20.6 | 20.65
# 20.68 | 20.65 | 20.7
# 20.72 | 20.7 | 20.75
# 20.78 | 20.75 | 20.8
# 20.82 | 20.8 | 20.85
# 20.88 | 20.85 | 20.9
# 20.92 | 20.9 | 20.95
# 20.98 | 20.95 | 21.0
# -------dileptonM-------
# 50.06 | 50.0 | 50.12
# 50.19 | 50.12 | 50.25
# 50.31 | 50.25 | 50.38
# 50.44 | 50.38 | 50.5
# 50.56 | 50.5 | 50.62
# 50.69 | 50.62 | 50.75
# 50.81 | 50.75 | 50.88
# 50.94 | 50.88 | 51.0
# 51.06 | 51.0 | 51.12
# 51.19 | 51.12 | 51.25
# 51.31 | 51.25 | 51.38
# 51.44 | 51.38 | 51.5
# 51.56 | 51.5 | 51.62
# 51.69 | 51.62 | 51.75
# 51.81 | 51.75 | 51.88
# 51.94 | 51.88 | 52.0
# 52.06 | 52.0 | 52.12
# 52.19 | 52.12 | 52.25
# 52.31 | 52.25 | 52.38
# 52.44 | 52.38 | 52.5

# %%
jumps = {}
for v in var:
    print("-------"+v+"-------")
    jumps[v]  = {}
    for c in cb[v][cb[v]>=0][:-1]:
        #cbLabel = round(c+ptcut,2)
        cbLabel = c+ptcut[v]
        print(cbLabel)
        jumps[v][cbLabel] = count[v][cbLabel]*cdf[v][c]
# Out:
# -------photonOnePt-------
# 15.0
# 15.307692307692308
# 15.615384615384617
# 15.923076923076923
# 16.23076923076923
# 16.53846153846154
# 16.846153846153847
# 17.153846153846153
# 17.461538461538463
# 17.76923076923077
# 18.076923076923077
# 18.384615384615387
# 18.692307692307693
# 19.0
# 19.307692307692307
# 19.615384615384617
# 19.923076923076923
# 20.230769230769234
# 20.53846153846154
# 20.846153846153847
# 21.153846153846153
# 21.461538461538463
# 21.76923076923077
# 22.07692307692308
# 22.384615384615387
# 22.692307692307693
# 23.0
# 23.307692307692307
# 23.615384615384617
# 23.923076923076923
# 24.230769230769234
# 24.53846153846154
# -------leptonOnePt-------
# 25.0375
# 25.1125
# 25.1875
# 25.2625
# 25.3375
# 25.4125
# 25.4875
# 25.5625
# 25.6375
# 25.7125
# 25.7875
# 25.8625
# 25.9375
# 26.0125
# 26.0875
# 26.1625
# 26.2375
# 26.3125
# 26.3875
# -------leptonTwoPt-------
# 20.025
# 20.075
# 20.125
# 20.175
# 20.225
# 20.275
# 20.325
# 20.375
# 20.425
# 20.475
# 20.525
# 20.575
# 20.625
# 20.675
# 20.725
# 20.775
# 20.825
# 20.875
# 20.925
# -------dileptonM-------
# 50.0625
# 50.1875
# 50.3125
# 50.4375
# 50.5625
# 50.6875
# 50.8125
# 50.9375
# 51.0625
# 51.1875
# 51.3125
# 51.4375
# 51.5625
# 51.6875
# 51.8125
# 51.9375
# 52.0625
# 52.1875
# 52.3125

# %%
add = 0
for v in var:
    add += sum(jumps[v].values())/len(getattr(M,v))*100
    print(v,sum(jumps[v].values())/len(getattr(M,v))*100)
print("Total ",round(add,2),round(add*2,2))
# Out:
# photonOnePt 3.511695602589747
# leptonOnePt 0.02375045944869298
# leptonTwoPt 0.0737949782274062
# dileptonM 0.016471204151923987
# Total  3.63 7.25

# %%
cdf[v]
# Out:
# {-2.4375: 0.9996572313893782,
#  -2.3125: 0.9993076074065441,
#  -2.1875: 0.9988277313516737,
#  -2.0625: 0.9982415970275106,
#  -1.9375: 0.9975252106313113,
#  -1.8125: 0.9966408676159072,
#  -1.6875: 0.9955302973174929,
#  -1.5625: 0.9942209212249179,
#  -1.4375: 0.9926064810688896,
#  -1.3125: 0.9905772908940091,
#  -1.1875: 0.9878797019284162,
#  -1.0625: 0.9843628959834374,
#  -0.9375: 0.9794167449321661,
#  -0.8125: 0.9728218768638043,
#  -0.6875: 0.963046116088873,
#  -0.5625: 0.9481185430962974,
#  -0.4375: 0.922270362169314,
#  -0.3125: 0.8705945664319844,
#  -0.1875: 0.7528124164501512,
#  -0.0625: 0.5053643287562298,
#  0.0625: 0.2528981086028066,
#  0.1875: 0.1331279006793674,
#  0.3125: 0.0805060635767219,
#  0.4375: 0.05351646317636816,
#  0.5625: 0.03790678064865532,
#  0.6875: 0.02797677399894427,
#  0.8125: 0.021320207580670592,
#  0.9375: 0.016370628843293048,
#  1.0625: 0.012792124548402355,
h = np.histogram(M.photonOnePt,range = [0,120],bins =40)

# %%
N = len(M.photonOnePt)

edge = cb[v][cb[v]>=0]+ptcut -0.25
cdfPt = {}
#for i in range(1,len(h[1])):
#    cdfPt[h[1][i]] = sum(np.logical_and(M.photonOnePt > h[1][i-1], M.photonOnePt < h[1][i]))/N
#    #cdfPt[h[1][i]] = sum(M.photonOnePt > h[1][i-1])/N
    

for i in range(1,len(edge)):
    #cdfPt[edge[i]] = sum(M.photonOnePt > edge[i-1])/N
    cdfPt[edge[i]] = sum(np.logical_and(M.photonOnePt > edge[i-1],M.photonOnePt < edge[i]))/N
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-69153639eaa9> in <module>()
#       1 N = len(M.photonOnePt)
#       2
# ----> 3 edge = cb[v][cb[v]>=0]+ptcut -0.25
#       4 cdfPt = {}
#       5 #for i in range(1,len(h[1])):
#
# TypeError: unsupported operand type(s) for +: 'float' and 'dict'

# %%
plt.plot(cdfPt.keys(),cdfPt.values())

# %%
v = "photonOnePt"
###############################################
fig = plt.figure()
#plt.subplot(1,3,1)
histoPt = plt.hist(
        [getattr(merg,v+"_x"),getattr(merg,v+"_y")],
        histtype = 'step',
        #range    = plotSet[v][1],
        range    = [min(jumps.keys()),max(jumps.keys())],
        bins     = len(jumps.keys()),
        #bins     = plotSet[v][0],
        #bins = edge,
        label    = ['rerecy','legacy']
        )

plt.bar(
        cb[v][cb[v]>=0][:-1]+ptcut+0.4,
        jumps.values(),
        label = 'jumps'
        )

plt.title("Rereco-Legacy Comparison")
plt.xlabel(v)
plt.grid(linestyle = '--')
plt.legend()
fig.savefig(figpath+"/"+v+"Jumps.png")

# %%
for v in VAR:

    fig = plt.figure(figsize=(20,6))

    ###############################################

    plt.subplot(1,3,1)
    plt.hist(
            [getattr(merg,v+"_x"),getattr(merg,v+"_y")],
            histtype = 'step',
            range    = plotSet[v][1],
            bins     = plotSet[v][0],
            label    = ['rerecy','legacy']
            )
    plt.title("Rereco-Legacy Comparison")
    plt.xlabel(v)
    plt.grid(linestyle = '--')
    plt.legend()
    #fig.savefig(figpath+"/"+v+"Diff.png")

    ###############################################

    plt.subplot(1,3,2)
    histo[v] = plt.hist(
            getattr(merg,v+"_x")-getattr(merg,v+"_y"),
            histtype = 'step',
            range    = plotSetDiff[v][1],
            bins     = plotSetDiff[v][0],
            )
    plt.title("Legacy-Rereco Comparison")
    plt.xlabel(v+" diff")
    plt.grid(linestyle = '--')
    #fig.savefig(figpath+"/"+v+"Diff.png")

    ###############################################

    cb[v] = (histo[v][1][1:]+histo[v][1][:-1])/2
    #N = sum(getattr(merg,v+"_x"))
    N = sum(histo[v][0])

    cdf[v] = {}
    for c in cb[v]:
        cdfi = sum(histo[v][0][c<cb[v]])/N
        cdf[v][c] = cdfi
        #print(c,cdfi)

    plt.subplot(1,3,3)
    plt.plot(cb[v],cdf[v].values())
    plt.title(v+"Diff CDF")
    plt.xlabel(v+" diff")
    plt.grid(linestyle='--')
    plt.show()
    #fig.savefig(figpath+"PtCDF.png")    

    ###############################################

    fig.savefig(figpath+"/"+v+".png")
